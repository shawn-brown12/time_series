# %% [markdown]
# # Part 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import acquire

# %% [markdown]
# The end result of this exercise should be a file named prepare.py.
#
# Using your store items data:
#
# Convert date column to datetime format.

# %%
df = acquire.acquire_store()

# %%
df.head()
# Out:
#     sale_date  sale_amount item_brand                       item_name  \
# 0  2013-01-01           13   Riceland  Riceland American Jazmine Rice
# 1  2013-01-02           11   Riceland  Riceland American Jazmine Rice
# 2  2013-01-03           14   Riceland  Riceland American Jazmine Rice
# 3  2013-01-04           13   Riceland  Riceland American Jazmine Rice
# 4  2013-01-05           10   Riceland  Riceland American Jazmine Rice
#
#    item_price           store_address  store_zipcode
# 0        0.84  12125 Alamo Ranch Pkwy          78253
# 1        0.84  12125 Alamo Ranch Pkwy          78253
# 2        0.84  12125 Alamo Ranch Pkwy          78253
# 3        0.84  12125 Alamo Ranch Pkwy          78253
# 4        0.84  12125 Alamo Ranch Pkwy          78253

# %%
df.dtypes
# Out:
# sale_date         object
# sale_amount        int64
# item_brand        object
# item_name         object
# item_price       float64
# store_address     object
# store_zipcode      int64
# dtype: object

# %%
df['sale_date'] = pd.to_datetime(df['sale_date'], infer_datetime_format=True)

# %% [markdown]
# Plot the distribution of sale_amount and item_price.

# %%
sns.histplot(data=df, x='sale_amount')
# Out:
# <AxesSubplot:xlabel='sale_amount', ylabel='Count'>

# %%
sns.histplot(data=df, x='item_price')
# Out:
# <AxesSubplot:xlabel='item_price', ylabel='Count'>

# %%
df['item_price'].plot()
plt.show()

# %% [markdown]
# Set the index to be the datetime variable.

# %%
df = df.set_index('sale_date')

# %%
df = df.sort_index()

# %%
df.head()
# Out:
#             sale_amount  item_brand  \
# sale_date
# 2013-01-01           13    Riceland
# 2013-01-01           26     Mueller
# 2013-01-01           27  Mama Marys
# 2013-01-01           54     Mueller
# 2013-01-01           35     Mueller
#
#                                                     item_name  item_price  \
# sale_date
# 2013-01-01                     Riceland American Jazmine Rice        0.84
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01                                        Pizza Sauce        4.65
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
#
#                      store_address  store_zipcode
# sale_date
# 2013-01-01  12125 Alamo Ranch Pkwy          78253
# 2013-01-01  12018 Perrin Beitel Rd          78217
# 2013-01-01  12018 Perrin Beitel Rd          78217
# 2013-01-01     15000 San Pedro Ave          78232
# 2013-01-01      735 SW Military Dr          78221

# %% [markdown]
# Add a 'month' and 'day of week' column to your dataframe.

# %%
df['month'] = df.index.month_name()

df.head()
# Out:
#             sale_amount  item_brand  \
# sale_date
# 2013-01-01           13    Riceland
# 2013-01-01           26     Mueller
# 2013-01-01           27  Mama Marys
# 2013-01-01           54     Mueller
# 2013-01-01           35     Mueller
#
#                                                     item_name  item_price  \
# sale_date
# 2013-01-01                     Riceland American Jazmine Rice        0.84
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01                                        Pizza Sauce        4.65
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
#
#                      store_address  store_zipcode    month
# sale_date
# 2013-01-01  12125 Alamo Ranch Pkwy          78253  January
# 2013-01-01  12018 Perrin Beitel Rd          78217  January
# 2013-01-01  12018 Perrin Beitel Rd          78217  January
# 2013-01-01     15000 San Pedro Ave          78232  January
# 2013-01-01      735 SW Military Dr          78221  January

# %%
df['day'] = df.index.day_name()

df.head()
# Out:
#             sale_amount  item_brand  \
# sale_date
# 2013-01-01           13    Riceland
# 2013-01-01           26     Mueller
# 2013-01-01           27  Mama Marys
# 2013-01-01           54     Mueller
# 2013-01-01           35     Mueller
#
#                                                     item_name  item_price  \
# sale_date
# 2013-01-01                     Riceland American Jazmine Rice        0.84
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01                                        Pizza Sauce        4.65
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
#
#                      store_address  store_zipcode    month      day
# sale_date
# 2013-01-01  12125 Alamo Ranch Pkwy          78253  January  Tuesday
# 2013-01-01  12018 Perrin Beitel Rd          78217  January  Tuesday
# 2013-01-01  12018 Perrin Beitel Rd          78217  January  Tuesday
# 2013-01-01     15000 San Pedro Ave          78232  January  Tuesday
# 2013-01-01      735 SW Military Dr          78221  January  Tuesday

# %% [markdown]
# Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.

# %%
df['sales_total'] = df['sale_amount'] * df['item_price']

# %%
df.head()
# Out:
#             sale_amount  item_brand  \
# sale_date
# 2013-01-01           13    Riceland
# 2013-01-01           26     Mueller
# 2013-01-01           27  Mama Marys
# 2013-01-01           54     Mueller
# 2013-01-01           35     Mueller
#
#                                                     item_name  item_price  \
# sale_date
# 2013-01-01                     Riceland American Jazmine Rice        0.84
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01                                        Pizza Sauce        4.65
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
#
#                      store_address  store_zipcode  month  day  sales_total
# sale_date
# 2013-01-01  12125 Alamo Ranch Pkwy          78253      1    1        10.92
# 2013-01-01  12018 Perrin Beitel Rd          78217      1    1       218.40
# 2013-01-01  12018 Perrin Beitel Rd          78217      1    1       125.55
# 2013-01-01     15000 San Pedro Ave          78232      1    1       453.60
# 2013-01-01      735 SW Military Dr          78221      1    1       294.00

# %% [markdown]
# Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
df.head()
# Out:
#             sale_amount  item_brand  \
# sale_date
# 2013-01-01           13    Riceland
# 2013-01-01           26     Mueller
# 2013-01-01           27  Mama Marys
# 2013-01-01           54     Mueller
# 2013-01-01           35     Mueller
#
#                                                     item_name  item_price  \
# sale_date
# 2013-01-01                     Riceland American Jazmine Rice        0.84
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01                                        Pizza Sauce        4.65
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
#
#                      store_address  store_zipcode  month  day  sales_total
# sale_date
# 2013-01-01  12125 Alamo Ranch Pkwy          78253      1    1        10.92
# 2013-01-01  12018 Perrin Beitel Rd          78217      1    1       218.40
# 2013-01-01  12018 Perrin Beitel Rd          78217      1    1       125.55
# 2013-01-01     15000 San Pedro Ave          78232      1    1       453.60
# 2013-01-01      735 SW Military Dr          78221      1    1       294.00

# %%
def store_distributions(df):
    
    vars_to_plot = ['sale_amount', 'item_price', 'sales_total']

    for col in vars_to_plot:
    
        df.groupby('sale_date')[vars_to_plot].sum().plot()
        
        plt.show()

# %%
def wrangle_store_data():
    
    df = acquire.acquire_store()
    
    df['sale_date'] = pd.to_datetime(df['sale_date'], infer_datetime_format=True)
    df = df.set_index('sale_date')
    df = df.sort_index()
    
    df['month'] = df.index.month_name()
    df['day'] = df.index.day_name()
    
    df['sales_total'] = df['sale_amount'] * df['item_price']
    
    return df

# %%
df = wrangle_store_data()

# %%
df.head()
# Out:
#             sale_amount  item_brand  \
# sale_date
# 2013-01-01           13    Riceland
# 2013-01-01           26     Mueller
# 2013-01-01           27  Mama Marys
# 2013-01-01           54     Mueller
# 2013-01-01           35     Mueller
#
#                                                     item_name  item_price  \
# sale_date
# 2013-01-01                     Riceland American Jazmine Rice        0.84
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01                                        Pizza Sauce        4.65
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
#
#                      store_address  store_zipcode  month  day  sales_total
# sale_date
# 2013-01-01  12125 Alamo Ranch Pkwy          78253      1    1        10.92
# 2013-01-01  12018 Perrin Beitel Rd          78217      1    1       218.40
# 2013-01-01  12018 Perrin Beitel Rd          78217      1    1       125.55
# 2013-01-01     15000 San Pedro Ave          78232      1    1       453.60
# 2013-01-01      735 SW Military Dr          78221      1    1       294.00

# %%
store_distributions(df)

# %% [markdown]
# # Part 2

# %%
germany = pd.read_csv('https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv')

# %%
germany.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN

# %% [markdown]
# Using the OPS data acquired in the Acquire exercises opsd_germany_daily.csv, complete the following:
#
# Convert date column to datetime format.

# %%
germany.dtypes
# Out:
# Date           datetime64[ns]
# Consumption           float64
# Wind                  float64
# Solar                 float64
# Wind+Solar            float64
# dtype: object

# %%
germany['Date'] = pd.to_datetime(germany['Date'], infer_datetime_format=True)

# %% [markdown]
# Plot the distribution of each of your variables.

# %%
for col in germany:
    
    sns.histplot(germany[col])
    plt.title([col])
    plt.show()

# %% [markdown]
# Set the index to be the datetime variable.

# %%
germany = germany.set_index('Date').sort_index()

# %%
germany
# Out:
#             Consumption     Wind   Solar  Wind+Solar
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN
# 2006-01-02   1380.52100      NaN     NaN         NaN
# 2006-01-03   1442.53300      NaN     NaN         NaN
# 2006-01-04   1457.21700      NaN     NaN         NaN
# 2006-01-05   1477.13100      NaN     NaN         NaN
# ...                 ...      ...     ...         ...
# 2017-12-27   1263.94091  394.507  16.530     411.037
# 2017-12-28   1299.86398  506.424  14.162     520.586
# 2017-12-29   1295.08753  584.277  29.854     614.131
# 2017-12-30   1215.44897  721.247   7.467     728.714
# 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 4 columns]

# %% [markdown]
# Add a month and a year column to your dataframe.

# %%
germany['month'] = germany.index.month

# %%
germany['year'] = germany.index.year

# %%
germany.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar  month  year
# Date
# 2006-01-01     1069.184   0.0    0.0         0.0      1  2006
# 2006-01-02     1380.521   0.0    0.0         0.0      1  2006
# 2006-01-03     1442.533   0.0    0.0         0.0      1  2006
# 2006-01-04     1457.217   0.0    0.0         0.0      1  2006
# 2006-01-05     1477.131   0.0    0.0         0.0      1  2006

# %% [markdown]
# Fill any missing values.

# %%
germany['Wind'] = germany['Wind'].fillna(value=0)

# %%
germany['Solar'] = germany['Solar'].fillna(value=0)

# %%
germany['Wind+Solar'] = germany['Wind+Solar'].fillna(value=0)

# %%
germany.isna().sum()
# Out:
# Consumption    0
# Wind           0
# Solar          0
# Wind+Solar     0
# month          0
# year           0
# dtype: int64

# %% [markdown]
# Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
def germany_distributions(df):
    
    vars_to_plot = ['Consumption', 'Wind', 'Solar', 'Wind+Solar']

    for col in vars_to_plot:
    
        df.groupby('Date')[vars_to_plot].sum().plot()
    
        plt.show()

# %%
def wrangle_germany():
    
    df = pd.read_csv('https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv')
    
    df['Date'] = pd.to_datetime(df['Date'], infer_datetime_format=True)
    df = df.set_index('Date')
    df = df.sort_index()
    
    df['month'] = df.index.month
    df['year'] = df.index.year
    
    df['Wind'] = df['Wind'].fillna(value=0)
    df['Solar'] = df['Solar'].fillna(value=0)
    df['Wind+Solar'] = df['Wind+Solar'].fillna(value=0)
    
    return df

# %%
df = wrangle_germany()

# %%
df.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar  month  year
# Date
# 2006-01-01     1069.184   0.0    0.0         0.0      1  2006
# 2006-01-02     1380.521   0.0    0.0         0.0      1  2006
# 2006-01-03     1442.533   0.0    0.0         0.0      1  2006
# 2006-01-04     1457.217   0.0    0.0         0.0      1  2006
# 2006-01-05     1477.131   0.0    0.0         0.0      1  2006

# %%
germany_distributions(df)

# %% [markdown]
# # Class review notes
